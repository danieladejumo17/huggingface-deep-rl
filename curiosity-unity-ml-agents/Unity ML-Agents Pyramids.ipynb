# %% [markdown]
# ### Clone the HF Fork of ML-Agents

# %%
# !git clone https://github.com/huggingface/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 84252, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 84252 (delta 79), reused 185 (delta 66), pack-reused 84051
# Receiving objects: 100% (84252/84252), 2.48 GiB | 27.17 MiB/s, done.
# Resolving deltas: 100% (61525/61525), done.
# Checking out files: 100% (2106/2106), done.

# %% [markdown]
# Install the package

# %%
# %%capture

# %cd ml-agents
# Install the environment before installing the agent
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ### Download the executable

# %%
# !mkdir -p ./trained-envs-executables/linux

# %%
# !cp "/content/drive/MyDrive/Python/Machine Learning/HuggingFace-Deep-RL/curiosity-unity-ml-agents/Pyramids-linux.zip" "/content/ml-agents/trained-envs-executables/linux"

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H" -O ./trained-envs-executables/linux/Pyramids.zip && rm -rf /tmp/cookies.txt

# %%
# %%capture
# !unzip ./trained-envs-executables/linux/Pyramids-linux.zip -d trained-envs-executables/linux/

# %%
# make the Pyramids file executable

# !chmod -R 755 ./trained-envs-executables/linux/Pyramids/Pyramids

# %% [markdown]
# ### Train the Agent

# %%
# Train for 1,000,000 steps
# Use --resume to resume a previous run-id

# !mlagents-learn ./config/ppo/PyramidsRND.yaml --env=./trained-envs-executables/linux/Pyramids/Pyramids --run-id="Pyramids Training" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# ...

# %% [markdown]
# ## Push to HF Hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# ...

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
# !mlagents-push-to-hf --run-id="Pyramids Training" --local-dir="./results/Pyramids Training" --repo-id="danieladejumo/MLAgents-Pyramids" --commit-message="Fixed bash bug - mlagents-learn not found"
# Out:
# Pyramids Training
# danieladejumo/MLAgents-Pyramids
# This function will create a model card and upload your Pyramids Training into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  MLAgents-Pyramids
# ORGANIZATION:  danieladejumo
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:94: FutureWarning: `name` and `organization` input arguments are deprecated and will be removed in v0.10. Pass `repo_id` instead.
#   FutureWarning,
# Cloning https://huggingface.co/danieladejumo/MLAgents-Pyramids into local empty directory.
# Download file Pyramids/Pyramids-1252618.pt:   2% 152k/8.25M [00:01<00:55, 153kB/s]
# Download file Pyramids/events.out.tfevents.1658672915.410d80450fc1.212.0:   2% 7.58k/388k [00:00<?, ?B/s]
#
# Download file Pyramids/Pyramids-499879.onnx:   0% 1.58k/1.35M [00:00<?, ?B/s]
#
#
# Download file Pyramids/Pyramids-999994.onnx:   1% 16.0k/1.35M [00:00<?, ?B/s]
#
#
#
# ...
