# %% [markdown]
# ![cover](https://miro.medium.com/max/700/1*8DV9EFl-vdijvcTHilHuEw.png)

# %% [markdown]
# #Pyramids Unity3D

# %% [markdown]
# ##Getting Started

# %%
# %%capture
# Clone the repository
# !git clone https://github.com/huggingface/ml-agents/

# %%
# %%capture
# Go inside the repository and install the package
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ## Download and move the zip file in `./trained-envs-executables/linux/`

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %% [markdown]
# Download the file Pyramids.zip from https://drive.google.com/uc?export=download&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H using `wget`. Check out the full solution to download large files from GDrive [here](https://bcrf.biochem.wisc.edu/2021/02/05/download-google-drive-files-using-wget/)

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H" -O ./trained-envs-executables/linux/Pyramids.zip && rm -rf /tmp/cookies.txt
# Out:
# --2022-07-24 14:28:23--  https://docs.google.com/uc?export=download&confirm=t&id=1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H
# Resolving docs.google.com (docs.google.com)... 173.194.193.102, 173.194.193.100, 173.194.193.113, ...
# Connecting to docs.google.com (docs.google.com)|173.194.193.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/28nnn8u50goe446ulabvdigp6oeglk7p/1658672850000/09764732090272539193/*/1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H?e=download&uuid=e472a382-e402-4065-aab9-bdd073c5d55c [following]
# Warning: wildcards not supported in HTTP.
# --2022-07-24 14:28:23--  https://doc-04-8c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/28nnn8u50goe446ulabvdigp6oeglk7p/1658672850000/09764732090272539193/*/1UiFNdKlsH0NTu32xV-giYUEVKV4-vc7H?e=download&uuid=e472a382-e402-4065-aab9-bdd073c5d55c
# Resolving doc-04-8c-docs.googleusercontent.com (doc-04-8c-docs.googleusercontent.com)... 142.251.6.132, 2607:f8b0:4001:c5a::84
# Connecting to doc-04-8c-docs.googleusercontent.com (doc-04-8c-docs.googleusercontent.com)|142.251.6.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42907187 (41M) [application/zip]
# Saving to: ‘./trained-envs-executables/linux/Pyramids.zip’
#
# ./trained-envs-exec 100%[===================>]  40.92M  63.6MB/s    in 0.6s
#
# 2022-07-24 14:28:24 (63.6 MB/s) - ‘./trained-envs-executables/linux/Pyramids.zip’ saved [42907187/42907187]

# %% [markdown]
# **OR** Download directly to local machine and then drag and drop the file from local machine to `./trained-envs-executables/linux`

# %% [markdown]
# Wait for the upload to finish and then run the command below.
#
# ![image.png](data:image/png;base64,...)

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Pyramids.zip

# %% [markdown]
# Make sure your file is accessible

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Pyramids/Pyramids

# %% [markdown]
# ##Train
#
# Train the model and use the `--resume` flag to continue training in case of interruption.
#
#
#
# > It will fail first time when you use `--resume`, try runign the block again to bypass the error.

# %%
# !mlagents-learn ./config/ppo/PyramidsRND.yaml --env=./trained-envs-executables/linux/Pyramids/Pyramids --run-id="Pyramids Training" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# E0724 14:28:28.301337818     219 fork_posix.cc:76]           Other threads are currently calling into gRPC, skipping fork() handlers
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Pyramids?team=0
# [INFO] Hyperparameters for behavior name Pyramids:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	128
# 	  buffer_size:	2048
# 	  learning_rate:	0.0003
# 	  beta:	0.01
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	512
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	  rnd:
# 	    gamma:	0.99
# 	    strength:	0.01
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	64
# 	      num_layers:	3
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	    learning_rate:	0.0001
# 	    encoding_size:	None
# 	init_path:	None
# 	keep_checkpoints:	5
# 	checkpoint_interval:	500000
# 	max_steps:	3000000
# 	time_horizon:	128
# 	summary_freq:	30000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Pyramids. Step: 30000. Time Elapsed: 65.110 s. Mean Reward: -1.000. Std of Reward: 0.000. Training.
# [INFO] Pyramids. Step: 60000. Time Elapsed: 122.188 s. Mean Reward: -0.937. Std of Reward: 0.350. Training.
# [INFO] Pyramids. Step: 90000. Time Elapsed: 179.238 s. Mean Reward: -1.000. Std of Reward: 0.000. Training.
# [INFO] Pyramids. Step: 120000. Time Elapsed: 235.643 s. Mean Reward: -0.921. Std of Reward: 0.448. Training.
# [INFO] Pyramids. Step: 150000. Time Elapsed: 291.926 s. Mean Reward: -0.934. Std of Reward: 0.360. Training.
# [INFO] Pyramids. Step: 180000. Time Elapsed: 351.888 s. Mean Reward: -0.725. Std of Reward: 0.727. Training.
# [INFO] Pyramids. Step: 210000. Time Elapsed: 409.050 s. Mean Reward: -0.400. Std of Reward: 1.005. Training.
# [INFO] Pyramids. Step: 240000. Time Elapsed: 467.924 s. Mean Reward: -0.514. Std of Reward: 0.939. Training.
# [INFO] Pyramids. Step: 270000. Time Elapsed: 527.721 s. Mean Reward: 0.313. Std of Reward: 1.208. Training.
# [INFO] Pyramids. Step: 300000. Time Elapsed: 588.930 s. Mean Reward: 0.562. Std of Reward: 1.181. Training.
# [INFO] Pyramids. Step: 330000. Time Elapsed: 651.818 s. Mean Reward: 0.431. Std of Reward: 1.228. Training.
# [INFO] Pyramids. Step: 360000. Time Elapsed: 715.757 s. Mean Reward: 0.872. Std of Reward: 1.103. Training.
# [INFO] Pyramids. Step: 390000. Time Elapsed: 780.563 s. Mean Reward: 0.925. Std of Reward: 1.091. Training.
# [INFO] Pyramids. Step: 420000. Time Elapsed: 847.802 s. Mean Reward: 1.201. Std of Reward: 0.924. Training.
# [INFO] Pyramids. Step: 450000. Time Elapsed: 911.066 s. Mean Reward: 1.373. Std of Reward: 0.682. Training.
# [INFO] Pyramids. Step: 480000. Time Elapsed: 974.671 s. Mean Reward: 1.387. Std of Reward: 0.728. Training.
# [INFO] Exported results/Pyramids Training/Pyramids/Pyramids-499879.onnx
# [INFO] Pyramids. Step: 510000. Time Elapsed: 1041.098 s. Mean Reward: 1.355. Std of Reward: 0.811. Training.
# [INFO] Pyramids. Step: 540000. Time Elapsed: 1108.154 s. Mean Reward: 1.455. Std of Reward: 0.635. Training.
# [INFO] Pyramids. Step: 570000. Time Elapsed: 1173.325 s. Mean Reward: 1.411. Std of Reward: 0.705. Training.
# [INFO] Pyramids. Step: 600000. Time Elapsed: 1241.281 s. Mean Reward: 1.567. Std of Reward: 0.536. Training.
# [INFO] Pyramids. Step: 630000. Time Elapsed: 1312.176 s. Mean Reward: 1.628. Std of Reward: 0.323. Training.
# [INFO] Pyramids. Step: 660000. Time Elapsed: 1382.087 s. Mean Reward: 1.571. Std of Reward: 0.584. Training.
# [INFO] Pyramids. Step: 690000. Time Elapsed: 1451.204 s. Mean Reward: 1.616. Std of Reward: 0.439. Training.
# [INFO] Pyramids. Step: 720000. Time Elapsed: 1522.133 s. Mean Reward: 1.645. Std of Reward: 0.438. Training.
# [INFO] Pyramids. Step: 750000. Time Elapsed: 1591.572 s. Mean Reward: 1.591. Std of Reward: 0.504. Training.
# [INFO] Pyramids. Step: 780000. Time Elapsed: 1661.269 s. Mean Reward: 1.652. Std of Reward: 0.420. Training.
# [INFO] Pyramids. Step: 810000. Time Elapsed: 1731.684 s. Mean Reward: 1.650. Std of Reward: 0.423. Training.
# [INFO] Pyramids. Step: 840000. Time Elapsed: 1802.251 s. Mean Reward: 1.657. Std of Reward: 0.407. Training.
# [INFO] Pyramids. Step: 870000. Time Elapsed: 1873.444 s. Mean Reward: 1.595. Std of Reward: 0.579. Training.
# [INFO] Pyramids. Step: 900000. Time Elapsed: 1942.730 s. Mean Reward: 1.655. Std of Reward: 0.331. Training.
# [INFO] Pyramids. Step: 930000. Time Elapsed: 2013.455 s. Mean Reward: 1.629. Std of Reward: 0.434. Training.
# [INFO] Pyramids. Step: 960000. Time Elapsed: 2087.635 s. Mean Reward: 1.669. Std of Reward: 0.461. Training.
# [INFO] Pyramids. Step: 990000. Time Elapsed: 2157.798 s. Mean Reward: 1.670. Std of Reward: 0.332. Training.
# [INFO] Exported results/Pyramids Training/Pyramids/Pyramids-999994.onnx
# [INFO] Pyramids. Step: 1020000. Time Elapsed: 2231.349 s. Mean Reward: 1.676. Std of Reward: 0.419. Training.
# [INFO] Pyramids. Step: 1050000. Time Elapsed: 2303.479 s. Mean Reward: 1.643. Std of Reward: 0.421. Training.
# [INFO] Pyramids. Step: 1080000. Time Elapsed: 2373.439 s. Mean Reward: 1.735. Std of Reward: 0.158. Training.
# [INFO] Pyramids. Step: 1110000. Time Elapsed: 2443.858 s. Mean Reward: 1.545. Std of Reward: 0.677. Training.
# [INFO] Pyramids. Step: 1140000. Time Elapsed: 2515.544 s. Mean Reward: 1.720. Std of Reward: 0.379. Training.
# [INFO] Pyramids. Step: 1170000. Time Elapsed: 2588.155 s. Mean Reward: 1.669. Std of Reward: 0.409. Training.
# [INFO] Pyramids. Step: 1200000. Time Elapsed: 2660.534 s. Mean Reward: 1.716. Std of Reward: 0.291. Training.
# [INFO] Pyramids. Step: 1230000. Time Elapsed: 2735.862 s. Mean Reward: 1.746. Std of Reward: 0.274. Training.
# [INFO] Learning was interrupted. Please wait while the graph is generated.
# [INFO] Exported results/Pyramids Training/Pyramids/Pyramids-1252618.onnx
# [INFO] Copied results/Pyramids Training/Pyramids/Pyramids-1252618.onnx to results/Pyramids Training/Pyramids.onnx.

# %% [markdown]
# ## Save the model to Hugging face

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
# !git config --global credential.helper store

# %% [markdown]
# Make changes so that it save to your id and correct run-id

# %%
# !mlagents-push-to-hf --run-id="Pyramids Training" --local-dir="./results/Pyramids Training" --repo-id="danieladejumo/MLAgents-Pyramids" --commit-message="First Trained Agent Commit"
# Out:
# Pyramids Training
# danieladejumo/MLAgents-Pyramids
# This function will create a model card and upload your Pyramids Training into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  MLAgents-Pyramids
# ORGANIZATION:  danieladejumo
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:94: FutureWarning: `name` and `organization` input arguments are deprecated and will be removed in v0.10. Pass `repo_id` instead.
#   FutureWarning,
# Cloning https://huggingface.co/danieladejumo/MLAgents-Pyramids into local empty directory.
# Upload file Pyramids/Pyramids-1252618.pt:   0% 3.34k/8.25M [00:00<?, ?B/s]
# Upload file Pyramids/Pyramids-1252618.pt:   7% 551k/8.25M [00:01<00:14, 560kB/s]
# Upload file Pyramids/Pyramids-999994.pt:   5% 431k/8.25M [00:01<00:18, 437kB/s]
#
# Upload file Pyramids/events.out.tfevents.1658672915.410d80450fc1.212.0:   1% 3.34k/388k [00:00<?, ?B/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:   0% 3.34k/8.25M [00:00<?, ?B/s]
#
#
#
# Upload file Pyramids/Pyramids-999994.onnx:   0% 3.34k/1.35M [00:00<?, ?B/s]
#
#
#
#
# Upload file Pyramids.onnx:   0% 3.34k/1.35M [00:00<?, ?B/s]
#
#
#
#
#
# Upload file Pyramids/Pyramids-1252618.pt:  17% 1.39M/8.25M [00:02<00:09, 754kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  15% 1.27M/8.25M [00:02<00:10, 704kB/s]
#
# Upload file Pyramids/events.out.tfevents.1658672915.410d80450fc1.212.0:   2% 7.34k/388k [00:01<01:35, 4.09kB/s]
#
#
#
# Upload file Pyramids/Pyramids-999994.onnx:   1% 7.34k/1.35M [00:01<05:44, 4.09kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:   0% 7.34k/8.25M [00:01<35:13, 4.09kB/s]
#
#
#
#
# Upload file Pyramids.onnx:   1% 7.34k/1.35M [00:01<05:44, 4.09kB/s]
#
#
#
#
#
# Upload file Pyramids/Pyramids-499879.onnx:   1% 7.34k/1.35M [00:01<05:44, 4.09kB/s]
#
#
#
# Upload file Pyramids/Pyramids-999994.onnx:  43% 599k/1.35M [00:02<00:02, 357kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  23% 1.87M/8.25M [00:03<00:10, 664kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:   7% 603k/8.25M [00:02<00:22, 359kB/s]
#
#
#
#
#
# Upload file Pyramids/Pyramids-1252618.pt:  24% 1.98M/8.25M [00:03<00:09, 688kB/s]
#
#
#
#
# Upload file Pyramids.onnx:  45% 619k/1.35M [00:02<00:02, 368kB/s]
#
#
#
#
#
# Upload file Pyramids/Pyramids-499879.onnx:  96% 1.30M/1.35M [00:03<00:00, 535kB/s]
#
#
#
#
# Upload file Pyramids.onnx:  98% 1.32M/1.35M [00:03<00:00, 543kB/s]
#
#
#
# Upload file Pyramids/Pyramids-999994.onnx:  48% 663k/1.35M [00:03<00:03, 224kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  12% 999k/8.25M [00:03<00:20, 379kB/s]
#
#
#
# Upload file Pyramids/Pyramids-999994.onnx:  99% 1.34M/1.35M [00:04<00:00, 419kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  20% 1.64M/8.25M [00:04<00:13, 505kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  23% 1.93M/8.25M [00:05<00:21, 308kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  32% 2.63M/8.25M [00:06<00:13, 429kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  29% 2.37M/8.25M [00:05<00:10, 597kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  41% 3.35M/8.25M [00:07<00:09, 523kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  37% 3.09M/8.25M [00:06<00:08, 650kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  46% 3.80M/8.25M [00:07<00:06, 679kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  49% 4.06M/8.25M [00:08<00:07, 588kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  54% 4.49M/8.25M [00:08<00:05, 693kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  58% 4.75M/8.25M [00:09<00:05, 628kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  63% 5.23M/8.25M [00:09<00:04, 719kB/s]
# Upload file Pyramids/Pyramids-1252618.pt:  33% 2.74M/8.25M [00:11<00:26, 218kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  73% 5.98M/8.25M [00:10<00:03, 740kB/s]
#
#
# Upload file Pyramids/Pyramids-1252618.pt:  43% 3.52M/8.25M [00:12<00:15, 319kB/s]
# Upload file Pyramids/Pyramids-1252618.pt:  52% 4.33M/8.25M [00:13<00:09, 423kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt:  91% 7.54M/8.25M [00:12<00:00, 779kB/s]
# Upload file Pyramids/Pyramids-999994.pt:  68% 5.61M/8.25M [00:13<00:09, 299kB/s]
# Upload file Pyramids/Pyramids-1252618.pt:  57% 4.72M/8.25M [00:14<00:08, 419kB/s]
# Upload file Pyramids/Pyramids-1252618.pt:  67% 5.49M/8.25M [00:15<00:05, 510kB/s]
# Upload file Pyramids/Pyramids-1252618.pt:  84% 6.96M/8.25M [00:17<00:02, 627kB/s]To https://huggingface.co/danieladejumo/MLAgents-Pyramids
#    f72e865..9ca9d8f  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/danieladejumo/MLAgents-Pyramids
#    f72e865..9ca9d8f  main -> main
#
# Upload file Pyramids/Pyramids-1252618.pt: 100% 8.25M/8.25M [00:19<00:00, 454kB/s]
#
# Upload file Pyramids/Pyramids-999994.pt: 100% 8.25M/8.25M [00:19<00:00, 383kB/s]
# Upload file Pyramids/Pyramids-999994.pt: 100% 8.25M/8.25M [00:19<00:00, 454kB/s]
#
#
# Upload file Pyramids/events.out.tfevents.1658672915.410d80450fc1.212.0: 100% 388k/388k [00:18<00:00, 22.1kB/s]
#
# Upload file Pyramids/events.out.tfevents.1658672915.410d80450fc1.212.0: 100% 388k/388k [00:18<00:00, 21.8kB/s]
#
#
#
# Upload file Pyramids/Pyramids-499879.pt: 100% 8.25M/8.25M [00:18<00:00, 305kB/s]
#
#
# Upload file Pyramids/Pyramids-499879.pt: 100% 8.25M/8.25M [00:18<00:00, 479kB/s]
#
#
#
#
# Upload file Pyramids/Pyramids-999994.onnx: 100% 1.35M/1.35M [00:18<00:00, 78.3kB/s]
#
#
#
#
#
# Upload file Pyramids.onnx: 100% 1.35M/1.35M [00:18<00:00, 78.3kB/s]
#
#
#
#
#
#
# Upload file Pyramids/Pyramids-499879.onnx: 100% 1.35M/1.35M [00:18<00:00, 78.3kB/s]
#
#  Your model is pushed to the hub. You can view your model here: https://huggingface.co/danieladejumo/MLAgents-Pyramids
