# %% [markdown]
# ### Clone the HF Fork of ML-Agents

# %%
# !git clone https://github.com/huggingface/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 84252, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 84252 (delta 79), reused 185 (delta 66), pack-reused 84051
# Receiving objects: 100% (84252/84252), 2.48 GiB | 29.22 MiB/s, done.
# Resolving deltas: 100% (61533/61533), done.

# %% [markdown]
# Install the package

# %%
# %%capture

# %cd ml-agents
# Install the environment before installing the agent
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ### Download the executable

# %%
# !mkdir -p ./trained-envs-executables/linux

# %%
# !cp "/content/drive/MyDrive/Python/Machine Learning/HuggingFace-Deep-RL/curiosity-unity-ml-agents/Worm-linux.zip" "/content/ml-agents/trained-envs-executables/linux"

# %%
# %%capture
# !unzip ./trained-envs-executables/linux/Worm-linux.zip -d trained-envs-executables/linux/

# %%
# make the Pyramids file executable

# !chmod -R 755 ./trained-envs-executables/linux/Worm/Worm

# %% [markdown]
# ### Train the Agent

# %%
# Train for 1,000,000 steps
# Use --resume to resume a previous run-id

# !mlagents-learn ./config/ppo/Worm.yaml --env=./trained-envs-executables/linux/Worm/Worm --run-id="Worm Training" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# ...

# %% [markdown]
# ## Push to HF Hub

# %%
# To enable notebook widgets

from google.colab import output
output.enable_custom_widget_manager()

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# If the notebook  widget is not working
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# ...

# %%
# !mlagents-push-to-hf --run-id="Worm Training" --local-dir="./results/Worm Training" --repo-id="danieladejumo/MLAgents-Worm" --commit-message="Firt Commit"
# Out:
# Worm Training
# danieladejumo/MLAgents-Worm
# This function will create a model card and upload your Worm Training into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  MLAgents-Worm
# ORGANIZATION:  danieladejumo
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:94: FutureWarning: `name` and `organization` input arguments are deprecated and will be removed in v0.10. Pass `repo_id` instead.
#   FutureWarning,
# Cloning https://huggingface.co/danieladejumo/MLAgents-Worm into local empty directory.
# Upload file Worm/Worm-1010000.pt:   0% 3.34k/12.9M [00:00<?, ?B/s]
# Upload file Worm/Worm-499000.onnx:   0% 3.34k/2.15M [00:00<?, ?B/s]
#
# Upload file Worm/Worm-999000.onnx:   0% 3.34k/2.15M [00:00<?, ?B/s]
#
#
# Upload file Worm.onnx:   0% 3.34k/2.15M [00:00<?, ?B/s]
#
#
#
# Upload file Worm/events.out.tfevents.1661170476.a8a3c02ec14a.449.0:   3% 3.34k/97.4k [00:00<?, ?B/s]
#
#
#
# ...
