# %% [markdown]
# ### Clone the HF Fork of ML-Agents

# %%
# !git clone https://github.com/huggingface/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 84252, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 84252 (delta 79), reused 185 (delta 66), pack-reused 84051
# Receiving objects: 100% (84252/84252), 2.48 GiB | 31.20 MiB/s, done.
# Resolving deltas: 100% (61525/61525), done.
# Checking out files: 100% (2106/2106), done.

# %% [markdown]
# Install the package

# %%
# %%capture

# %cd ml-agents
# Install the environment before installing the agent
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents

# %% [markdown]
# ### Download the executable

# %%
# !mkdir -p ./trained-envs-executables/linux

# %%
# !cp "/content/drive/MyDrive/Python/Machine Learning/HuggingFace-Deep-RL/curiosity-unity-ml-agents/PushBlock-linux.zip" "/content/ml-agents/trained-envs-executables/linux"

# %%
# %%capture
# !unzip ./trained-envs-executables/linux/PushBlock-linux.zip -d trained-envs-executables/linux/

# %%
# make the Pyramids file executable

# !chmod -R 755 ./trained-envs-executables/linux/PushBlock/PushBlock

# %% [markdown]
# ### Train the Agent

# %%
# Train SAC for 1,000,000 steps
# Use --resume to resume a previous run-id

# !mlagents-learn ./config/sac/PushBlock.yaml --env=./trained-envs-executables/linux/PushBlock/PushBlock --run-id="PushBlock Training" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.29.0.dev0,
#   ml-agents-envs: 0.29.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.8.1+cu102
# ...

# %% [markdown]
# ## Push to HF Hub

# %%
# To enable notebook widgets

from google.colab import output
output.enable_custom_widget_manager()

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
# If the notebook  widget is not working
# !huggingface-cli login

# %%
# !mlagents-push-to-hf --run-id="PushBlock Training" --local-dir="./results/PushBlock Training" --repo-id="danieladejumo/MLAgents-PushBlock" --commit-message="Firt Commit"
# Out:
# PushBlock Training
# danieladejumo/MLAgents-PushBlock
# This function will create a model card and upload your PushBlock Training into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# REPO NAME:  MLAgents-PushBlock
# ORGANIZATION:  danieladejumo
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/hf_api.py:94: FutureWarning: `name` and `organization` input arguments are deprecated and will be removed in v0.10. Pass `repo_id` instead.
#   FutureWarning,
# Cloning https://huggingface.co/danieladejumo/MLAgents-PushBlock into local empty directory.
# Upload file PushBlock/PushBlock-1000019.pt:   1% 75.3k/6.04M [00:01<01:24, 73.6kB/s]
# Upload file PushBlock.onnx:   1% 3.34k/477k [00:00<?, ?B/s]
#
# Upload file PushBlock/events.out.tfevents.1661242883.4db74e0ca094.398.0:   3% 3.34k/103k [00:00<?, ?B/s]
#
#
# Upload file PushBlock/PushBlock-499984.onnx:   1% 3.34k/477k [00:00<?, ?B/s]
#
#
#
# ...
